# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import accuracy_score


def identificate_gresit(nume_fisiere, y):
    linii_gresite=[]
    linii = nume_fisiere.shape[0]                           
    for i in range(linii):                                 
        if nume_fisiere[i][2] == "#":
            nota = nume_fisiere[i][:3]                      
        else:
            nota = nume_fisiere[i][:2]                     
        if sorted(y[i]) != sorted(nota):                    
            linii_gresite.append(i+2)                       
            print("Nota identificata gresit in pe randul {}, nota adevarata {}, " \
                  "nota falsa {}.".format(i+2, nota, y[i]))
    print("\nNumar note identificate gresit: " \
          "{}.".format(len(linii_gresite)))
    
    return linii_gresite


def schimbare_clase(nume_fisiere, y, linii_gresite):
    indecsi_gresiti = [i - 2 for i in linii_gresite]
    for i in indecsi_gresiti:
        if nume_fisiere[i][2] == "#":
            y[i] = nume_fisiere[i][:3]
        else:
            y[i] = nume_fisiere[i][:2]
    print("\nClase gresite schimbate.")
    
    return 0


def stergere_clase(nume_fisiere, X, y, linii_gresite):
    indecsi_gresiti = [i - 2 for i in linii_gresite]
    nume_fisiere = np.delete(nume_fisiere, indecsi_gresiti)
    X = np.delete(X, indecsi_gresiti)
    y = np.delete(y, indecsi_gresiti)
    print("\nClase gresite sterse.")
             
    return nume_fisiere, X, y


def kmeans_acuratete(clustere, clase):
    dictionar = {}
    clustere_unice = np.unique(clustere)
    for i in range(len(clustere_unice)):
        masca = np.where(clustere == i, 1, 0)
        aparitii_etichete = np.bincount(clase[masca==1])
        eticheta_aleasa = aparitii_etichete.argmax()
        dictionar[i] = eticheta_aleasa

    clustere_clase = np.random.rand(len(clustere))
    for i in range(len(clustere)):
        clustere_clase[i] = dictionar[clustere[i]]

    acuratete = accuracy_score(clustere_clase, clase)
    
    return acuratete, clustere_clase

# %%
# AUTOCORELATIE
# 0. Se pastreaza etichetele date de formula

# %%
df = pd.read_csv('autocor_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)
# Out:
# Acuratete: 0.9821882951653944
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# AUTOCORELATIE
# 1. Se modifica etichetele cu cele bune

# %%
df = pd.read_csv('autocor_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

linii_gresite = identificate_gresit(nume_fisiere, note)
schimbare_clase(nume_fisiere, note, linii_gresite)
linii_gresite = identificate_gresit(nume_fisiere, note)

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)
# Out:
# Nota identificata gresit in pe randul 4, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 14, nota adevarata A3, nota falsa A2.
# Nota identificata gresit in pe randul 36, nota adevarata A4, nota falsa A2.
# Nota identificata gresit in pe randul 46, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 51, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 53, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 54, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 55, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 68, nota adevarata B3, nota falsa B2.
# Nota identificata gresit in pe randul 78, nota adevarata B4, nota falsa G2.
# Nota identificata gresit in pe randul 119, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 128, nota adevarata C4#, nota falsa D#4.
# Nota identificata gresit in pe randul 131, nota adevarata C4, nota falsa C3.
# Nota identificata gresit in pe randul 193, nota adevarata D4#, nota falsa G#2.
# Nota identificata gresit in pe randul 224, nota adevarata D5#, nota falsa D#4.
# Nota identificata gresit in pe randul 234, nota adevarata D5, nota falsa D4.
# Nota identificata gresit in pe randul 245, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 250, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 252, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 269, nota adevarata F3#, nota falsa F#2.
# Nota identificata gresit in pe randul 279, nota adevarata F3, nota falsa F2.
# Nota identificata gresit in pe randul 289, nota adevarata F4#, nota falsa B2.
# Nota identificata gresit in pe randul 296, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 310, nota adevarata F4, nota falsa E4.
# Nota identificata gresit in pe randul 330, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 343, nota adevarata G3, nota falsa G2.
# Nota identificata gresit in pe randul 380, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 381, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 382, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 383, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 384, nota adevarata G5#, nota falsa G#4.
#
# Numar note identificate gresit: 31.
#
# Clase gresite schimbate.
#
# Numar note identificate gresit: 0.
# Acuratete: 0.9312977099236641
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# AUTOCORELATIE
# 2. Se sterg datele gresite

# %%
df = pd.read_csv('autocor_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

linii_gresite = identificate_gresit(nume_fisiere, note)
nume_fisiere, frecvente, note = stergere_clase(nume_fisiere, frecvente, note, linii_gresite)
linii_gresite = identificate_gresit(nume_fisiere, note)

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)
# Out:
# Nota identificata gresit in pe randul 4, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 14, nota adevarata A3, nota falsa A2.
# Nota identificata gresit in pe randul 36, nota adevarata A4, nota falsa A2.
# Nota identificata gresit in pe randul 46, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 51, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 53, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 54, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 55, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 68, nota adevarata B3, nota falsa B2.
# Nota identificata gresit in pe randul 78, nota adevarata B4, nota falsa G2.
# Nota identificata gresit in pe randul 119, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 128, nota adevarata C4#, nota falsa D#4.
# Nota identificata gresit in pe randul 131, nota adevarata C4, nota falsa C3.
# Nota identificata gresit in pe randul 193, nota adevarata D4#, nota falsa G#2.
# Nota identificata gresit in pe randul 224, nota adevarata D5#, nota falsa D#4.
# Nota identificata gresit in pe randul 234, nota adevarata D5, nota falsa D4.
# Nota identificata gresit in pe randul 245, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 250, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 252, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 269, nota adevarata F3#, nota falsa F#2.
# Nota identificata gresit in pe randul 279, nota adevarata F3, nota falsa F2.
# Nota identificata gresit in pe randul 289, nota adevarata F4#, nota falsa B2.
# Nota identificata gresit in pe randul 296, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 310, nota adevarata F4, nota falsa E4.
# Nota identificata gresit in pe randul 330, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 343, nota adevarata G3, nota falsa G2.
# Nota identificata gresit in pe randul 380, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 381, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 382, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 383, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 384, nota adevarata G5#, nota falsa G#4.
#
# Numar note identificate gresit: 31.
#
# Clase gresite sterse.
#
# Numar note identificate gresit: 0.
# Acuratete: 1.0
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# CEPSTRUM
# 0. Se pastreaza etichetele date de formula

# %%
df = pd.read_csv('cepstrum_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)
# Out:
# Acuratete: 0.9923664122137404
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# CEPSTRUM
# 1. Se modifica etichetele cu cele bune

# %%
df = pd.read_csv('cepstrum_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

linii_gresite = identificate_gresit(nume_fisiere, note)
schimbare_clase(nume_fisiere, note, linii_gresite)
linii_gresite = identificate_gresit(nume_fisiere, note)

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)

print('\n')
# Out:
# Nota identificata gresit in pe randul 4, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 11, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 31, nota adevarata A4#, nota falsa A#2.
# Nota identificata gresit in pe randul 45, nota adevarata A4, nota falsa G#4.
# Nota identificata gresit in pe randul 46, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 47, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 48, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 49, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 50, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 51, nota adevarata A5#, nota falsa F#3.
# Nota identificata gresit in pe randul 52, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 53, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 54, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 55, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 56, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 57, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 58, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 59, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 60, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 61, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 62, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 63, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 64, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 65, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 68, nota adevarata B3, nota falsa B2.
# Nota identificata gresit in pe randul 83, nota adevarata B4, nota falsa B3.
# Nota identificata gresit in pe randul 84, nota adevarata B4, nota falsa B3.
# Nota identificata gresit in pe randul 86, nota adevarata B4, nota falsa A#4.
# Nota identificata gresit in pe randul 87, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 88, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 89, nota adevarata B5, nota falsa B2.
# Nota identificata gresit in pe randul 91, nota adevarata B5, nota falsa E4.
# Nota identificata gresit in pe randul 92, nota adevarata B5, nota falsa B3.
# Nota identificata gresit in pe randul 93, nota adevarata B5, nota falsa E4.
# Nota identificata gresit in pe randul 94, nota adevarata B5, nota falsa C#3.
# Nota identificata gresit in pe randul 95, nota adevarata B5, nota falsa B3.
# Nota identificata gresit in pe randul 96, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 120, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 124, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 126, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 128, nota adevarata C4#, nota falsa D#3.
# Nota identificata gresit in pe randul 146, nota adevarata C5#, nota falsa F#3.
# Nota identificata gresit in pe randul 149, nota adevarata C5#, nota falsa F#3.
# Nota identificata gresit in pe randul 161, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 162, nota adevarata C6, nota falsa G#4.
# Nota identificata gresit in pe randul 163, nota adevarata C6, nota falsa F5.
# Nota identificata gresit in pe randul 164, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 165, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 166, nota adevarata C6, nota falsa A#5.
# Nota identificata gresit in pe randul 167, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 168, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 169, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 170, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 200, nota adevarata D4#, nota falsa D#3.
# Nota identificata gresit in pe randul 202, nota adevarata D4#, nota falsa D#3.
# Nota identificata gresit in pe randul 212, nota adevarata D4, nota falsa D3.
# Nota identificata gresit in pe randul 217, nota adevarata D5#, nota falsa D#4.
# Nota identificata gresit in pe randul 220, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 222, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 223, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 224, nota adevarata D5#, nota falsa B2.
# Nota identificata gresit in pe randul 227, nota adevarata D5, nota falsa D3.
# Nota identificata gresit in pe randul 230, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 231, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 232, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 233, nota adevarata D5, nota falsa D4.
# Nota identificata gresit in pe randul 234, nota adevarata D5, nota falsa D3.
# Nota identificata gresit in pe randul 257, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 258, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 259, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 260, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 261, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 262, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 263, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 264, nota adevarata E5, nota falsa C3.
# Nota identificata gresit in pe randul 265, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 294, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 295, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 296, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 299, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 300, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 301, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 305, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 308, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 316, nota adevarata F5#, nota falsa B3.
# Nota identificata gresit in pe randul 319, nota adevarata F5#, nota falsa B3.
# Nota identificata gresit in pe randul 321, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 322, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 325, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 326, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 327, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 328, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 329, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 330, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 353, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 355, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 357, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 360, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 375, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 376, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 377, nota adevarata G5#, nota falsa G#2.
# Nota identificata gresit in pe randul 378, nota adevarata G5#, nota falsa G#3.
# Nota identificata gresit in pe randul 379, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 380, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 381, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 382, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 383, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 384, nota adevarata G5#, nota falsa G#3.
# Nota identificata gresit in pe randul 394, nota adevarata G5, nota falsa G4.
#
# Numar note identificate gresit: 109.
#
# Clase gresite schimbate.
#
# Numar note identificate gresit: 0.
# Acuratete: 0.7913486005089059
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# CEPSTRUM
# 2. Se sterg datele gresite

# %%
df = pd.read_csv('cepstrum_trainsitest.csv')    
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values

linii_gresite = identificate_gresit(nume_fisiere, note)
nume_fisiere, frecvente, note = stergere_clase(nume_fisiere, frecvente, note, linii_gresite)
linii_gresite = identificate_gresit(nume_fisiere, note)

X = frecvente                            
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=49)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)

le = LabelEncoder()
clase = le.fit_transform(note)

acuratete, clustere_clase = kmeans_acuratete(clustere, clase)
print('Acuratete:', acuratete)

print('\n')
# Out:
# Nota identificata gresit in pe randul 4, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 11, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 31, nota adevarata A4#, nota falsa A#2.
# Nota identificata gresit in pe randul 45, nota adevarata A4, nota falsa G#4.
# Nota identificata gresit in pe randul 46, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 47, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 48, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 49, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 50, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 51, nota adevarata A5#, nota falsa F#3.
# Nota identificata gresit in pe randul 52, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 53, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 54, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 55, nota adevarata A5#, nota falsa A#2.
# Nota identificata gresit in pe randul 56, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 57, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 58, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 59, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 60, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 61, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 62, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 63, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 64, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 65, nota adevarata A5, nota falsa G#5.
# Nota identificata gresit in pe randul 68, nota adevarata B3, nota falsa B2.
# Nota identificata gresit in pe randul 83, nota adevarata B4, nota falsa B3.
# Nota identificata gresit in pe randul 84, nota adevarata B4, nota falsa B3.
# Nota identificata gresit in pe randul 86, nota adevarata B4, nota falsa A#4.
# Nota identificata gresit in pe randul 87, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 88, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 89, nota adevarata B5, nota falsa B2.
# Nota identificata gresit in pe randul 91, nota adevarata B5, nota falsa E4.
# Nota identificata gresit in pe randul 92, nota adevarata B5, nota falsa B3.
# Nota identificata gresit in pe randul 93, nota adevarata B5, nota falsa E4.
# Nota identificata gresit in pe randul 94, nota adevarata B5, nota falsa C#3.
# Nota identificata gresit in pe randul 95, nota adevarata B5, nota falsa B3.
# Nota identificata gresit in pe randul 96, nota adevarata B5, nota falsa C#4.
# Nota identificata gresit in pe randul 120, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 124, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 126, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 128, nota adevarata C4#, nota falsa D#3.
# Nota identificata gresit in pe randul 146, nota adevarata C5#, nota falsa F#3.
# Nota identificata gresit in pe randul 149, nota adevarata C5#, nota falsa F#3.
# Nota identificata gresit in pe randul 161, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 162, nota adevarata C6, nota falsa G#4.
# Nota identificata gresit in pe randul 163, nota adevarata C6, nota falsa F5.
# Nota identificata gresit in pe randul 164, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 165, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 166, nota adevarata C6, nota falsa A#5.
# Nota identificata gresit in pe randul 167, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 168, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 169, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 170, nota adevarata C6, nota falsa C#6.
# Nota identificata gresit in pe randul 200, nota adevarata D4#, nota falsa D#3.
# Nota identificata gresit in pe randul 202, nota adevarata D4#, nota falsa D#3.
# Nota identificata gresit in pe randul 212, nota adevarata D4, nota falsa D3.
# Nota identificata gresit in pe randul 217, nota adevarata D5#, nota falsa D#4.
# Nota identificata gresit in pe randul 220, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 222, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 223, nota adevarata D5#, nota falsa G#3.
# Nota identificata gresit in pe randul 224, nota adevarata D5#, nota falsa B2.
# Nota identificata gresit in pe randul 227, nota adevarata D5, nota falsa D3.
# Nota identificata gresit in pe randul 230, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 231, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 232, nota adevarata D5, nota falsa D#5.
# Nota identificata gresit in pe randul 233, nota adevarata D5, nota falsa D4.
# Nota identificata gresit in pe randul 234, nota adevarata D5, nota falsa D3.
# Nota identificata gresit in pe randul 257, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 258, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 259, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 260, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 261, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 262, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 263, nota adevarata E5, nota falsa E4.
# Nota identificata gresit in pe randul 264, nota adevarata E5, nota falsa C3.
# Nota identificata gresit in pe randul 265, nota adevarata E5, nota falsa A3.
# Nota identificata gresit in pe randul 294, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 295, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 296, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 299, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 300, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 301, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 305, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 308, nota adevarata F4, nota falsa F3.
# Nota identificata gresit in pe randul 316, nota adevarata F5#, nota falsa B3.
# Nota identificata gresit in pe randul 319, nota adevarata F5#, nota falsa B3.
# Nota identificata gresit in pe randul 321, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 322, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 325, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 326, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 327, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 328, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 329, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 330, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 353, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 355, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 357, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 360, nota adevarata G4#, nota falsa G#3.
# Nota identificata gresit in pe randul 375, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 376, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 377, nota adevarata G5#, nota falsa G#2.
# Nota identificata gresit in pe randul 378, nota adevarata G5#, nota falsa G#3.
# Nota identificata gresit in pe randul 379, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 380, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 381, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 382, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 383, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 384, nota adevarata G5#, nota falsa G#3.
# Nota identificata gresit in pe randul 394, nota adevarata G5, nota falsa G4.
#
# Numar note identificate gresit: 109.
#
# Clase gresite sterse.
#
# Numar note identificate gresit: 0.
# Acuratete: 1.0
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
# Plot clustere

#stergere greseli
df = pd.read_csv('autocor_trainsitest.csv')
nume_fisiere = df.iloc[:, 0].values
frecvente = df.iloc[:, 1].values
note = df.iloc[:, 2].values
X = frecvente
linii_gresite = identificate_gresit(nume_fisiere, note)
nume_fisiere, X, note = stergere_clase(nume_fisiere, X, note, linii_gresite)
linii_gresite = identificate_gresit(nume_fisiere, note)

# refacere dataset 
concat = np.column_stack((nume_fisiere, X, note))
indecsi = [i for i in range(X.shape[0])]
titlu = ['fisier', 'pitch', 'nota']
df_sterse = pd.DataFrame(data=concat,
                      index=indecsi,
                      columns=titlu)
# df_sterse.to_csv('autocor_trainsitest_sterse.csv', index=False)   #salvare ca fisier csv, fara indecsi

# K-means
X = X.reshape(-1,1)
kmeans = MiniBatchKMeans(n_clusters=37)
kmeans.fit(X)
clustere = kmeans.fit_predict(X)
erori_kmeans(note, clustere)      #script detectie erori

# Plot
df_cu_clustere = df_sterse.copy()
df_cu_clustere['cluster'] = clustere
# df_sterse.to_csv('autocor_trainsitest_sterse_clustere.csv', index=False)   #salvare ca fisier csv, fara indecsi
indecsi_csv = [i+2 for i in indecsi]
plt.figure(1)
plt.scatter(indecsi, df_cu_clustere['pitch'],
                c=df_cu_clustere['cluster'], cmap='rainbow')
plt.show()
# Out:
# Nota identificata gresit in pe randul 4, nota adevarata A3#, nota falsa A#2.
# Nota identificata gresit in pe randul 14, nota adevarata A3, nota falsa A2.
# Nota identificata gresit in pe randul 36, nota adevarata A4, nota falsa A2.
# Nota identificata gresit in pe randul 46, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 51, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 53, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 54, nota adevarata A5#, nota falsa A#4.
# Nota identificata gresit in pe randul 55, nota adevarata A5#, nota falsa D#4.
# Nota identificata gresit in pe randul 68, nota adevarata B3, nota falsa B2.
# Nota identificata gresit in pe randul 78, nota adevarata B4, nota falsa G2.
# Nota identificata gresit in pe randul 119, nota adevarata C4#, nota falsa C#3.
# Nota identificata gresit in pe randul 128, nota adevarata C4#, nota falsa D#4.
# Nota identificata gresit in pe randul 131, nota adevarata C4, nota falsa C3.
# Nota identificata gresit in pe randul 193, nota adevarata D4#, nota falsa G#2.
# Nota identificata gresit in pe randul 224, nota adevarata D5#, nota falsa D#4.
# Nota identificata gresit in pe randul 234, nota adevarata D5, nota falsa D4.
# Nota identificata gresit in pe randul 245, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 250, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 252, nota adevarata E4, nota falsa E3.
# Nota identificata gresit in pe randul 269, nota adevarata F3#, nota falsa F#2.
# Nota identificata gresit in pe randul 279, nota adevarata F3, nota falsa F2.
# Nota identificata gresit in pe randul 289, nota adevarata F4#, nota falsa B2.
# Nota identificata gresit in pe randul 296, nota adevarata F4#, nota falsa F#3.
# Nota identificata gresit in pe randul 310, nota adevarata F4, nota falsa E4.
# Nota identificata gresit in pe randul 330, nota adevarata F5, nota falsa F4.
# Nota identificata gresit in pe randul 343, nota adevarata G3, nota falsa G2.
# Nota identificata gresit in pe randul 380, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 381, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 382, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 383, nota adevarata G5#, nota falsa G#4.
# Nota identificata gresit in pe randul 384, nota adevarata G5#, nota falsa G#4.
#
# Numar note identificate gresit: 31.
#
# Clase gresite sterse.
#
# Numar note identificate gresit: 0.
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# D:\Installed\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14684/3298220162.py in <module>
#      25 kmeans.fit(X)
#      26 clustere = kmeans.fit_predict(X)
# ---> 27 erori_kmeans(note, clustere)      #script detectie erori
#      28
#      29 # Plot
#
# NameError: name 'erori_kmeans' is not defined
