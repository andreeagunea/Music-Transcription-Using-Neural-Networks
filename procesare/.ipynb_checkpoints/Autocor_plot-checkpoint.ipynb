# %%
import librosa, librosa.display
import matplotlib.pyplot as plt
import os
import math
import numpy as np
import csv
from scipy.signal import find_peaks

# %%
file = "A4.wav"

# %%
def nota_index_in_nota_octava(nota_index):
    note = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
    nota = (nota_index - 1) % len(note)
    nota = note[nota]
    octava = (nota_index + 8) // len(note)

    return nota, octava


def frecv_in_nota_index(pitch):
    if not pitch:  # daca avem o valoare diferita de 0
        pitch += 1e-15
    # formula luata de pe https://en.wikipedia.org/wiki/Piano_key_frequencies
    nota_index = 12 * math.log2(pitch / 440) + 49
    offset_from_note = nota_index
    nota_index = round(nota_index)
    offset_from_note -= nota_index
    nota = nota_index_in_nota_octava(nota_index)

    return nota

# %%
def autocorelatie(path_fisier):
    y, sr = librosa.load(path_fisier)

    plt.figure(figsize=(14, 5))
    librosa.display.waveplot(y, sr=sr)

    corr = np.correlate(y, y, 'full')[len(y) - 1:]

    peaks, dics = find_peaks(corr, height=0)
    top = np.argsort(corr[peaks])[-2:]
    ind = top[-1]
    pitch = sr / peaks[ind]

    plt.figure(figsize=(15,7))
    plt.plot(corr[:10000])
    plt.plot(peaks[top], corr[peaks[top]], "x")
    plt.xlabel('Lag (samples)')
    plt.xlim(0, 500)
    plt.show()

    nota = frecv_in_nota_index(pitch)
    nota = ''.join(map(str, nota))

    return nota, pitch

# %%
autocorelatie(file)
# Out:
# ('A4', 441.0)

# %%
from statsmodels.graphics.tsaplots import plot_acf
def autocorelatie2(path_fisier):
    y, sr = librosa.load(path_fisier)

    plt.figure(figsize=(14, 5))
    librosa.display.waveplot(y, sr=sr)

    corr = plot_acf(y, lags=90)
    
    peaks, dics = find_peaks(corr, height=0)
    top = np.argsort(corr[peaks])[-2:]
    ind = top[-1]
    pitch = sr / peaks[ind]

    plt.figure(figsize=(15,7))
    plt.plot(corr[:10000])
    plt.plot(peaks[top], corr[peaks[top]], "x")
    plt.xlabel('Lag (samples)')
    plt.xlim(0, 500)
    plt.show()

    nota = frecv_in_nota_index(pitch)
    nota = ''.join(map(str, nota))

    return nota, pitch

# %%
autocorelatie2(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9768/901892915.py in <module>
# ----> 1 autocorelatie2(file)
#
# ~\AppData\Local\Temp/ipykernel_9768/3231231394.py in autocorelatie2(path_fisier)
#       8     corr = plot_acf(y, lags=90)
#       9
# ---> 10     peaks, dics = find_peaks(corr, height=0)
#      11     top = np.argsort(corr[peaks])[-2:]
#      12     ind = top[-1]
#
# D:\Installed\Anaconda\lib\site-packages\scipy\signal\_peak_finding.py in find_peaks(x, height, threshold, distance, prominence, width, wlen, rel_height, plateau_size)
#     930     """
#     931     # _argmaxima1d expects array of dtype 'float64'
# --> 932     x = _arg_x_as_expected(x)
#     933     if distance is not None and distance < 1:
#     934         raise ValueError('`distance` must be greater or equal to 1')
#
# D:\Installed\Anaconda\lib\site-packages\scipy\signal\_peak_finding.py in _arg_x_as_expected(value)
#     259         A 1-D C-contiguous array with dtype('float64').
#     260     """
# --> 261     value = np.asarray(value, order='C', dtype=np.float64)
#     262     if value.ndim != 1:
#     263         raise ValueError('`x` must be a 1-D array')
#
# D:\Installed\Anaconda\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'Figure'

# %%
def serial_corr(wave, lag=1):
    n = len(wave)
    y1 = wave.ys[lag:]
    y2 = wave.ys[:n-lag]
    corr = np.corrcoef(y1, y2, ddof=0)[0, 1]
    return corr

def autocorr(wave):
    lags = range(len(wave.ys)//2)
    corrs = [serial_corr(wave, lag) for lag in lags]
    return lags, corrs

lags, corrs = autocorr(file)
plt.plot(lags, corrs)

period = lag / file.framerate
frequency = 1 / period
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9768/471810468.py in <module>
#      11     return lags, corrs
#      12
# ---> 13 lags, corrs = autocorr(file)
#      14 plt.plot(lags, corrs)
#      15
#
# ~\AppData\Local\Temp/ipykernel_9768/471810468.py in autocorr(wave)
#       7
#       8 def autocorr(wave):
# ----> 9     lags = range(len(wave.ys)//2)
#      10     corrs = [serial_corr(wave, lag) for lag in lags]
#      11     return lags, corrs
#
# AttributeError: 'str' object has no attribute 'ys'

# %%
y, sr = librosa.load(file)

# %%
y.ys
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9768/3905884425.py in <module>
# ----> 1 y.ys
#
# AttributeError: 'numpy.ndarray' object has no attribute 'ys'
